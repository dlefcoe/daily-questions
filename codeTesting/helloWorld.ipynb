# %%
msg = 'hello world'
print(msg)
# Out:
# hello world

# %% [markdown]
# for i in range(20):
#     print('hello',i)

# %% [markdown]
# print(i)
# x = range(20)
# print(len(range(20)))

# %% [markdown]
# print(i)

# %%
class HelloTest:
    something = 'hello'

    def __init__(self, me):
        self.me = me
        self.you = None

h = HelloTest('darren')

print(h.me)
# Out:
# darren

# %%
h.you = 'steve'
print(h.__dict__)
# Out:
# {'me': 'darren', 'you': 'steve'}

# %%
h2 = HelloTest('bob')
print(h2.__dict__)
# Out:
# {'me': 'bob', 'you': None}

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0,20,100)
plt.plot(x, np.sin(x))
plt.show()
